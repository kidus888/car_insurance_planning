# %%
import sys
import os
sys.path.append('../scripts')

# %%
import pandas as pd
from eda import txt_to_csv, load_data, data_summary, check_missing_values, plot_histograms, plot_categorical_bar, calculate_correlation, scatter_plot, box_plot

# %%
# Specify the paths for the input .txt file and output .csv file
txt_file_path = '../data/dataset.txt'  # Update the path
csv_file_path = '../data/dataset.csv'  # Output CSV path

# Convert the .txt file to .csv
txt_to_csv(txt_file_path, csv_file_path)

# Now load the newly created CSV for further analysis
df = load_data(csv_file_path)
# Out:
# /home/kali/Desktop/vs/car_insurance_planning/notebooks/../scripts/eda.py:12: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(txt_file_path, delimiter=delimiter)
# File successfully converted and saved as ../data/dataset.csv
# /home/kali/Desktop/vs/car_insurance_planning/notebooks/../scripts/eda.py:28: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)

# %%
print(df.head())
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
# Perform data summarization
print("Data Summary:")
print(data_summary(df))
# Out:
# Data Summary:
#         UnderwrittenCoverID      PolicyID     TransactionMonth  \
# count          1.000098e+06  1.000098e+06              1000098
# unique                  NaN           NaN                   23
# top                     NaN           NaN  2015-08-01 00:00:00
# freq                    NaN           NaN               106747
# mean           1.048175e+05  7.956682e+03                  NaN
# std            6.329371e+04  5.290039e+03                  NaN
# min            1.000000e+00  1.400000e+01                  NaN
# 25%            5.514300e+04  4.500000e+03                  NaN
# 50%            9.408300e+04  7.071000e+03                  NaN
# 75%            1.391900e+05  1.107700e+04                  NaN
# max            3.011750e+05  2.324600e+04                  NaN
#
#        IsVATRegistered Citizenship   LegalType    Title Language  \
# count          1000098     1000098     1000098  1000098  1000098
# ...

# %%
# Check for missing values
print("Missing Values:")
print(check_missing_values(df))
# Out:
# Missing Values:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# ...

# %%
# Plot histograms for numerical columns
numerical_columns = ['TotalPremium', 'TotalClaims', 'SumInsured']  # Add more columns if needed
plot_histograms(df, numerical_columns)

# %%
# Plot bar charts for categorical columns
categorical_columns = ['IsVATRegistered', 'Citizenship', 'Gender']  # Add more columns if needed
plot_categorical_bar(df, categorical_columns)

# %%
# Correlation analysis
correlation_columns = ['TotalPremium', 'TotalClaims', 'SumInsured']
print("Correlation Matrix:")
calculate_correlation(df, correlation_columns)
# Out:
# Correlation Matrix:
#               TotalPremium  TotalClaims  SumInsured
# TotalPremium      1.000000     0.121588   -0.041174
# TotalClaims       0.121588     1.000000   -0.005129
# SumInsured       -0.041174    -0.005129    1.000000

# %%
# Scatter plot for TotalPremium vs TotalClaims
scatter_plot(df, 'TotalPremium', 'TotalClaims')

# %%
# Outlier detection using box plots
box_plot(df, 'TotalPremium')
box_plot(df, 'TotalClaims')
